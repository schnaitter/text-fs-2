# %%
import requests

# %%
from bs4 import BeautifulSoup, Tag, Comment

# %% [markdown]
# ### Retrieve and save HTML

# %%
url = "https://www.berlin.de/rbmskzl/"

# %%
response = requests.get(url)

# %%
response.status_code
# Out:
# 200

# %%
html_text = response.text

# %%
html_text[:100]
# Out:
# '<!doctype html>\n<html xmlns="http://www.w3.org/1999/xhtml" xml:lang="de" lang="de">\n<head prefix="og'

# %%
with open('berlin_rbmskzl_main_page.html', 'w') as openfile:
    openfile.write(html_text)

# %% [markdown]
# ### Get text of the HTML
# (same as in the [brandenburg notebook](https://github.com/dh-network/quadriga-fs-2/blob/develop/html_parsing/brandenburg-landesportal.ipynb))

# %%
with open('berlin_rbmskzl_main_page.html') as openfile:
    html_text = openfile.read()

# %%
soup = BeautifulSoup(html_text)

# %%
# https://stackoverflow.com/questions/1936466/how-to-scrape-only-visible-webpage-text-with-beautifulsoup

# Only get text that is visible on the website 
# Inlcudes ads, pointers to more info and so on 

def tag_visible(element):
    if element.parent.name in ['style', 'script', 'head', 'title', 'meta', '[document]']:
        return False
    if isinstance(element, Comment):
        return False
    return True

def text_from_html(soup):
    texts = soup.findAll(string=True)
    visible_texts = filter(tag_visible, texts)  
    return [t.strip() for t in visible_texts if len(t) > 1]

# %%
text = text_from_html(soup)

# %%
text
# Out:
# ['Der Regierende Bürgermeister',
#  'Senatskanzlei',
#  'Informationen und Links zur Barrierefreiheit öffnen',
#  'Barrierefrei',
#  'Barrierefreiheit',
#  'Schließen: Barrierefreiheit',
#  'Leichte Sprache',
#  'DGS',
#  'Wie barrierefrei ist diese Webseite?',
#  'Erklärung zur Barrierefreiheit',
#  'Haben Sie Anmerkungen oder Fragen zur Barrierefreiheit dieser Webseite?',
#  'Kontakt zur Ansprechperson',
#  'Wo gibt es zusätzliche Informationen zur Barrierefreiheit im Land Berlin?',
#  'Landesbeauftragte für digitale Barrierefreiheit',
#  'Suche',
#  'Suche',
#  'Suche schließen',
#  'Suche auf der Internetseite',
#  'Suchen',
#  'Menü',
#  'Hauptnavigation',
#  'Menü schließen',
#  'Aktuelles',
#  'Termine',
#  'Abonnement',
#  'Presse\xadmitteilungen',
#  '2023',
#  '2022',
#  '2021',
#  'Suche und Abonnement',
#  'Media',
#  'Veranstaltungen',
#  'Kai Wegner vor Ort',
#  'Ausstellungen',
#  'Rückblick',
#  'Auszeichnungen und Ehrungen',
#  'Ehren\xadbürgerschaft Berlins',
#  'Ehren\xadgrabstätten',
#  'Ernst-Reuter-Plakette',
#  'Verdienstorden des Landes Berlin',
#  'Stadt\xadältesten\xadwürde',
#  'Berliner Wissen\xadschafts\xadpreis',
#  'Preis\xadträgerinnen und Preisträger',
#  'Berliner Ehrennadel',
#  'Ehren\xadpatenschaft',
#  'Suche',
#  'Social Media',
#  'Regierender Bürgermeister',
#  'Fokusthemen',
#  'Moderne Verwaltung',
#  'Bauen und Wohnen',
#  'Mobilität',
#  'Sicherheit',
#  'Klimaschutz',
#  'Bildung',
#  'Leichte Sprache',
#  'Politik',
#  'Senat',
#  'Senatsmitglieder',
#  'Landespolitik',
#  'Koalitionsvertrag',
#  'Richtlinien der Politik',
#  'Geschäfts\xadverteilung',
#  'Geschäfts\xadordnung',
#  'Verfassung',
#  'Senatsgalerie',
#  'Bürgermeister\xadgalerie',
#  'Senatskanzlei',
#  'Wir über uns',
#  'Abteilungen',
#  'Beschäftigtenvertretung',
#  'Smart City Berlin',
#  'Verwaltungssteuerung',
#  'Zukunftspakt',
#  'Gesamtstädtische Zielverein\xadbarungen',
#  'Berliner Verwaltungspreis',
#  'CityLAB Berlin',
#  'Aktuelles',
#  'Europaangelegenheiten',
#  'Internationales',
#  'Strategie und Ziele',
#  'Städtepartnerschaften',
#  'Städtenetzwerke',
#  'Partner',
#  'Bundesangelegenheiten',
#  'Aktuelles',
#  'Landesvertretung Berlin',
#  'Der Bundesrat',
#  'Der Deutsche Bundestag',
#  'Der Vermittlungs\xadausschuss',
#  'Die Ministerpräsident\xadenkonferenz',
#  'Die Ministerpräsi\xaddentenkonferenz Ost',
#  'Die Landes\xadvertretungen',
#  'Ausbildungs\xadmöglichkeiten',
#  'Medienpolitik',
#  'Rat der Bürgermeister',
#  'Service',
#  'Bürgerberatung',
#  'Rotes Rathaus',
#  'Baugeschichte',
#  'Steinerne Chronik',
#  'Besichtigung',
#  'Ausstellungen',
#  'Goldenes Buch',
#  'Berlin-Informationen',
#  'Zeitschrift aktuell',
#  'Publikationen',
#  'Wappen und Hoheitszeichen',
#  'Illumination Brandenburger Tor',
#  'Corporate Design',
#  'Neue Marke Berlin',
#  'Newsletter',
#  'Stellenaus\xadschreibungen',
#  'Information in other languages',
#  'English',
#  'Weiteres',
#  'twitter',
#  'facebook',
#  'instagram',
#  'linkedin',
#  'youtube',
#  'Der Regierende Bürgermeister von Berlin - Senatskanzlei',
#  'Bild: Landesarchiv Berlin / Grönboldt',
#  'Kai Wegner begrüßt Italiens Präsidenten Sergio Mattarella',
#  'Der Regierende Bürgermeister begrüßte den italienischen Präsidenten und seine Frau in Berlin am Brandenburger Tor.',
#  'Weitere Informationen',
#  'Bild:',
#  'Landesarchiv Berlin / Grönboldt',
#  'Wegner empfängt Jerusalemer Bürgermeister',
#  'Kai Wegner, empfing am 26. September den Bürgermeister von Jerusalem, Mosche Lion.',
#  'Weitere Informationen',
#  'Kai Wegner vor Ort',
#  'Der Regierende Bürgermeister besucht am 28. Oktober den Bezirk Kreuzberg-Friedrichshain und stellt sich den Fragen der Berlinerinnen und Berliner. Melden Sie sich an!',
#  'Weitere Informationen',
#  'Fokusthemen',
#  'Berlin steht vor diversen gesellschaftlichen Herausforderungen. Der Berliner Senat setzt einen Fokus auf sechs Themenschwerpunkte.',
#  'Weitere Informationen',
#  'Oft gesucht',
#  'Regierender Bürgermeister',
#  'Termine',
#  'Senatsmitglieder',
#  'Richtlinien der Politik',
#  'Fokusthemen',
#  'Rotes Rathaus',
#  'Ehrungen',
#  'Organigramm',
#  'Stellenausschreibungen',
#  'Bürgerberatung',
#  'Politische Themen',
#  'Bild: iStock.com/Bojan89',
#  'Moderne Verwaltung',
#  'Der Weg zum Amt - bald nur noch digital! Immer mehr Bürgerservices werden online angeboten.',
#  'Weitere Informationen',
#  'Bild: Sabine Zoltnere',
#  'Verwaltungssteuerung',
#  'Ziel ist die konkrete Stärkung der Dienstleistungsqualität der Berliner Verwaltung.',
#  'Weitere Informationen',
#  'Bild: Florian Reimann',
#  'Gemeinsam Digital',
#  'Visionäre Entwürfe und konkrete Baupläne: Die Smart City-Strategie für die Hauptstadt.',
#  'Weitere Informationen',
#  'Bild: Europareferat SenKultEU',
#  'Europa',
#  'Was hat Berlin mit Europa zu tun? Finden Sie es heraus!',
#  'Weitere Informationen',
#  'Bild: Landesarchiv Berlin, Wunstorf',
#  'Internationales',
#  'Das Land Berlin unterhält Partnerschaften mit 18 Metropolen auf der Welt.',
#  'Weitere Informationen',
#  'Bild: Mircea Moira / depositphotos.com',
#  'Medien',
#  'Der Senat hat das Ziel, Berlin als Filmmetropole weiter auszubauen und die Medienpolitik voranzutreiben.',
#  'Weitere Informationen',
#  'Pressemitteilungen',
#  '01.10.2024',
#  'Olympiapark wird Gebiet mit außergewöhnlicher stadtpolitischer Bedeutung',
#  '01.10.2024',
#  'Bebauungsplan ermöglicht Aufbau eines Katalyse-Forschungs- und Entwicklungszentrums',
#  '01.10.2024',
#  'Land Berlin reformiert Mietobergrenze bei Ersatzwohnraum',
#  'Weitere Pressemitteilungen',
#  'Weitere Informationen zu diesem Auftritt',
#  'Zur Startseite',
#  'zum Seitenanfang',
#  'Senatskanzlei',
#  'Impressum',
#  'Kontakt',
#  'Datenschutzerklärung',
#  'Erklärung zur Barrierefreiheit',
#  'DGS',
#  'Leichte Sprache',
#  'Fokusthemen',
#  'Moderne Verwaltung',
#  'Bauen und Wohnen',
#  'Mobilität und Verkehr',
#  'Sicherheit',
#  'Klimaschutz',
#  'Bildung',
#  'Politik',
#  'Landespolitik',
#  'Berliner Senat',
#  'Moderne Verwaltung',
#  'Europa',
#  'Internationales',
#  'Service',
#  'Bürgerberatung',
#  'Rotes Rathaus',
#  'Publikationen',
#  'Stellenausschreibungen',
#  'Ausstellungen',
#  'Fotos',
#  'Interessantes',
#  'Goldenes Buch',
#  'Ehrungen',
#  'Bürgermeistergalerie',
#  'Ukraine',
#  'Energieportal',
#  'MeinBerlin',
#  'Weitere Informationen zu Berlin.de',
#  'Service',
#  'Service-App',
#  'Termin vereinbaren',
#  'Bürgertelefon 115',
#  'Notdienste',
#  'Gewerbeservice',
#  'Behörden',
#  'Behörden A-Z',
#  'Senatsverwaltungen',
#  'Bezirksämter',
#  'Bürgerämter',
#  'Jobcenter',
#  'Einwanderungsamt',
#  'Politik & Verwaltung',
#  'Landesregierung',
#  'Karriere im Land Berlin',
#  'Bürgerbeteiligung',
#  'Open Data',
#  'Vergaben',
#  'Aktuelles',
#  'Pressemitteilungen',
#  'Polizeimeldungen',
#  'Veranstaltungen',
#  'Ukraine',
#  'Hitzeschutz',
#  'Themen',
#  'Fokusthemen',
#  'Berliner Verkehrswende',
#  'Moderne Verwaltung',
#  'Mietspiegel',
#  'Grundsteuer',
#  'Weitere Informationen',
#  'Kultur & Ausgehen',
#  'Tourismus',
#  'Wirtschaft',
#  'Stadtleben',
#  'Stadtplan',
#  'Berlin.de ist ein Angebot des Landes Berlin.']

# %% [markdown]
# ### Parse HTML (strukturierte parsen, one page)

# %% [markdown]
# #### 1. Parse the top news section of the website
#
# ![berlin_de_top](berlin_de_top.png)

# %% [markdown]
# If we inspect the unredlying HTML code, we'll see that it is in a `<div>` element with a CSS class `'herounit-homepage herounit-homepage--default'`. Let's retrieve this div using BeautifulSoup syntax:

# %%
topdiv = soup.find("div", {"class": "herounit-homepage herounit-homepage--default"})

# %%
type(topdiv)
# Out:
# bs4.element.Tag

# %%
print(topdiv.prettify())
# Out:
# <div class="herounit-homepage herounit-homepage--default">
#  <h1 class="title">
#   Der Regierende Bürgermeister von Berlin - Senatskanzlei
#  </h1>
#  <div class="modul-buehne buehne--tileslayout">
#   <ul class="buhne__list--teaser">
#    <li>
#     <div class="modul-teaser_buehne" data-add-clickable-area="smart">
#      <div class="teaser_buehne__left">
#       <div class="image">
#        <!-- Image.view -->
#        <div class="image__image image__image" style="">
#         <img alt="Kai Wegner begrüßt Italiens Präsidenten Sergio Mattarella am 27.09.2024" class="jpg" data-orig="/rbmskzl/aktuelles/media/crop_nan_653_nan_340.48333740234375_1500_1000_54ccaad2ef03c22d8972e5b4746e29dc_p1_06454.jpg" loading="lazy" src="/imgscaler/yWuwttGbcIvWYHeN-MVnduJIEruYklTI1VYn1G_jO0w/rbig2zu1/L3N5czExLXByb2QvcmJtc2t6bC9ha3R1ZWxsZXMvbWVkaWEvY3JvcF9uYW5fNjUzX25hbl8zNDAuNDgzMzM3NDAyMzQzNzVfMTUwMF8xMDAwXzU0Y2NhYWQyZWYwM2MyMmQ4OTcyZTViNDc0NmUyOWRjX3AxXzA2NDU0LmpwZw.jpg?ts=1727715705"/>
#        </div>
#        <p class="image__copyright">
#         Bild: Landesarchiv Berlin / Grönboldt
#        </p>
#        <!-- /Image.view -->
#       </div>
#      </div>
#      <div class="teaser_buehne__right">
#       <div class="inner">
#        <h2 class="title">
#         Kai Wegner begrüßt Italiens Präsidenten Sergio Mattarella
#        </h2>
#        <p class="text">
#         Der Regierende Bürgermeister begrüßte den italienischen Präsidenten und seine Frau in Berlin am Brandenburger Tor.
#        </p>
#        <span class="action">
#         <a aria-label="Link zu: Kai Wegner begrüßt Italiens Präsidenten Sergio Mattarella" class="more" href="/rbmskzl/aktuelles/media/kai-wegner-begruesst-italiens-praesidenten-sergio-mattarella-1490034.php" title=" Kai Wegner begrüßt Italiens Präsidenten Sergio Mattarella">
#          Weitere Informationen
#         </a>
#        </span>
#        <span class="image__copyright">
#         <strong>
#          Bild:
#         </strong>
#         Landesarchiv Berlin / Grönboldt
#        </span>
#       </div>
#      </div>
#      <li>
#       <div class="modul-teasertile_buehne" data-add-clickable-area="full">
#        <h2 class="title">
#         Wegner empfängt Jerusalemer Bürgermeister
#        </h2>
#        <p class="text">
#         Kai Wegner, empfing am 26. September den Bürgermeister von Jerusalem, Mosche Lion.
#        </p>
#        <span class="action">
#         <a aria-label="Link zu: Wegner empfängt Jerusalemer Bürgermeister" class="more" href="/rbmskzl/aktuelles/media/kai-wegner-empfaengt-jerusalems-buergermeister-mosch-lion-1489224.php" title="Wegner empfängt Jerusalemer Bürgermeister">
#          Weitere Informationen
#         </a>
#        </span>
#       </div>
#      </li>
#      <li>
#       <div class="modul-teasertile_buehne" data-add-clickable-area="full">
#        <h2 class="title">
#         Kai Wegner vor Ort
#        </h2>
#        <p class="text">
#         Der Regierende Bürgermeister besucht am 28. Oktober den Bezirk Kreuzberg-Friedrichshain und stellt sich den Fragen der Berlinerinnen und Berliner. Melden Sie sich an!
#        </p>
#        <span class="action">
#         <a aria-label="Link zu: Kai Wegner vor Ort" class="more" href="/rbmskzl/aktuelles/veranstaltungen/kai-wegner-vor-ort/" title="Kai Wegner vor Ort">
#          Weitere Informationen
#         </a>
#        </span>
#       </div>
#      </li>
#      <li>
#       <div class="modul-teasertile_buehne" data-add-clickable-area="full">
#        <h2 class="title">
#         Fokusthemen
#        </h2>
#        <p class="text">
#         Berlin steht vor diversen gesellschaftlichen Herausforderungen. Der Berliner Senat setzt einen Fokus auf sechs Themenschwerpunkte.
#        </p>
#        <span class="action">
#         <a aria-label="Link zu: Fokusthemen" class="more" href="/rbmskzl/fokusthemen/" title="Fokusthemen">
#          Weitere Informationen
#         </a>
#        </span>
#       </div>
#      </li>
#     </div>
#    </li>
#   </ul>
#  </div>
# </div>

# %%
topdiv_h2titles = topdiv.find_all('h2')

# %%
topdiv_h2titles
# Out:
# [<h2 class="title"> Kai Wegner begrüßt Italiens Präsidenten Sergio Mattarella</h2>,
#  <h2 class="title">Wegner empfängt Jerusalemer Bürgermeister</h2>,
#  <h2 class="title">Kai Wegner vor Ort</h2>,
#  <h2 class="title">Fokusthemen</h2>]

# %%
topdiv_texts =  topdiv.find_all('p', {"class":"text"})

# %%
topdiv_texts
# Out:
# [<p class="text">
#                      Der Regierende Bürgermeister begrüßte den italienischen Präsidenten und seine Frau in Berlin am Brandenburger Tor.                        </p>,
#  <p class="text">
#                  Kai Wegner, empfing am 26. September den Bürgermeister von Jerusalem, Mosche Lion.                        </p>,
#  <p class="text">
#                  Der Regierende Bürgermeister besucht am 28. Oktober den Bezirk Kreuzberg-Friedrichshain und stellt sich den Fragen der Berlinerinnen und Berliner. Melden Sie sich an!                        </p>,
#  <p class="text">
#                  Berlin steht vor diversen gesellschaftlichen Herausforderungen. Der Berliner Senat setzt einen Fokus auf sechs Themenschwerpunkte.                        </p>]

# %%
topdiv_texts = [x.text.strip() for x in topdiv_texts]

# %%
topdiv_texts
# Out:
# ['Der Regierende Bürgermeister begrüßte den italienischen Präsidenten und seine Frau in Berlin am Brandenburger Tor.',
#  'Kai Wegner, empfing am 26. September den Bürgermeister von Jerusalem, Mosche Lion.',
#  'Der Regierende Bürgermeister besucht am 28. Oktober den Bezirk Kreuzberg-Friedrichshain und stellt sich den Fragen der Berlinerinnen und Berliner. Melden Sie sich an!',
#  'Berlin steht vor diversen gesellschaftlichen Herausforderungen. Der Berliner Senat setzt einen Fokus auf sechs Themenschwerpunkte.']

# %%
topdiv_h2titles = [x.text.strip() for x in topdiv_h2titles]

# %%
resulting_data = []

for i, text in enumerate(topdiv_texts):
    new_entry = {}
    new_entry['title'] = topdiv_h2titles[i]
    new_entry['text'] = text
    resulting_data.append(new_entry)

# %%
resulting_data
# Out:
# [{'title': 'Kai Wegner begrüßt Italiens Präsidenten Sergio Mattarella',
#   'text': 'Der Regierende Bürgermeister begrüßte den italienischen Präsidenten und seine Frau in Berlin am Brandenburger Tor.'},
#  {'title': 'Wegner empfängt Jerusalemer Bürgermeister',
#   'text': 'Kai Wegner, empfing am 26. September den Bürgermeister von Jerusalem, Mosche Lion.'},
#  {'title': 'Kai Wegner vor Ort',
#   'text': 'Der Regierende Bürgermeister besucht am 28. Oktober den Bezirk Kreuzberg-Friedrichshain und stellt sich den Fragen der Berlinerinnen und Berliner. Melden Sie sich an!'},
#  {'title': 'Fokusthemen',
#   'text': 'Berlin steht vor diversen gesellschaftlichen Herausforderungen. Der Berliner Senat setzt einen Fokus auf sechs Themenschwerpunkte.'}]

# %% [markdown]
# ### Parse HTML for links

# %%
links = soup.find_all('a', href=True)

# %%
links[1]
# Out:
# <a href="/rbmskzl" title='Startseite von "Der Regierende Bürgermeister Senatskanzlei"'><span class="institution">Der Regierende Bürgermeister</span><span class="title">Senatskanzlei</span></a>

# %% [markdown]
# #### Separate internal and external links

# %%
internal_links = []
external_links = []

for link in links:
    link_url = link['href']
    if link_url.startswith('/'):
        internal_links.append(link_url)
    else:
        external_links.append(link_url)

# %%
external_links[:5]
# Out:
# ['https://www.berlin.de',
#  'https://twitter.com/RegBerlin',
#  'https://www.facebook.com/RegBerlin/',
#  'https://www.instagram.com/regberlin/',
#  'https://www.linkedin.com/company/regberlin/']

# %%
internal_links[:15]
# Out:
# ['/rbmskzl',
#  '/rbmskzl/leichte-sprache/',
#  '/rbmskzl/gebaerdensprache/',
#  '/rbmskzl/barrierefreiheitserklaerung.879589.php',
#  '/rbmskzl/barrierefreiheitserklaerung.879589.php#contactbfe',
#  '/rbmskzl/barrierefreiheitserklaerung.879589.php#contactbfelb',
#  '/rbmskzl/aktuelles/',
#  '/rbmskzl/aktuelles/termine/',
#  '/rbmskzl/aktuelles/termine/abonnement/',
#  '/rbmskzl/aktuelles/pressemitteilungen/',
#  '/rbmskzl/aktuelles/pressemitteilungen/2023/',
#  '/rbmskzl/aktuelles/pressemitteilungen/2022/',
#  '/rbmskzl/aktuelles/pressemitteilungen/2021/',
#  '/rbmskzl/aktuelles/pressemitteilungen/suche-und-abonnement/',
#  '/rbmskzl/aktuelles/media/']

# %% [markdown]
# #### parsing all internal links and getting text

# %%
all_links_data = []

for link in internal_links:
    data = {}
    full_url = f'https://www.berlin.de/{link}'
    response = requests.get(full_url)
    if response.status_code == 200:
        html_text = response.text
        soup = BeautifulSoup(html_text)
        text = text_from_html(soup)
        data['url'] = full_url
        data['text'] = text
        all_links_data.append(data)
    else:
        print(f'error {response.status_code}')
# Out:
# error 425
# error 425

# %%
len(all_links_data)
# Out:
# 170

# %%
all_links_data[:5]
# Out:
# [{'url': 'https://www.berlin.de//rbmskzl',
#   'text': ['Der Regierende Bürgermeister',
#    'Senatskanzlei',
#    'Informationen und Links zur Barrierefreiheit öffnen',
#    'Barrierefrei',
#    'Barrierefreiheit',
#    'Schließen: Barrierefreiheit',
#    'Leichte Sprache',
#    'DGS',
#    'Wie barrierefrei ist diese Webseite?',
#    'Erklärung zur Barrierefreiheit',
#    'Haben Sie Anmerkungen oder Fragen zur Barrierefreiheit dieser Webseite?',
#    'Kontakt zur Ansprechperson',
#    'Wo gibt es zusätzliche Informationen zur Barrierefreiheit im Land Berlin?',
#    'Landesbeauftragte für digitale Barrierefreiheit',
#    'Suche',
#    'Suche',
#    'Suche schließen',
#    'Suche auf der Internetseite',
#    'Suchen',
#    'Menü',
#    'Hauptnavigation',
#    'Menü schließen',
#    'Aktuelles',
#    'Termine',
#    'Abonnement',
#    'Presse\xadmitteilungen',
#    '2023',
#    '2022',
#    '2021',
#    'Suche und Abonnement',
#    'Media',
#    'Veranstaltungen',
#    'Kai Wegner vor Ort',
#    'Ausstellungen',
#    'Rückblick',
#    'Auszeichnungen und Ehrungen',
#    'Ehren\xadbürgerschaft Berlins',
#    'Ehren\xadgrabstätten',
#    'Ernst-Reuter-Plakette',
#    'Verdienstorden des Landes Berlin',
#    'Stadt\xadältesten\xadwürde',
#    'Berliner Wissen\xadschafts\xadpreis',
#    'Preis\xadträgerinnen und Preisträger',
#    'Berliner Ehrennadel',
#    'Ehren\xadpatenschaft',
#    'Suche',
#    'Social Media',
#    'Regierender Bürgermeister',
#    'Fokusthemen',
#    'Moderne Verwaltung',
#    'Bauen und Wohnen',
#    'Mobilität',
#    'Sicherheit',
#    'Klimaschutz',
#    'Bildung',
#    'Leichte Sprache',
#    'Politik',
#    'Senat',
#    'Senatsmitglieder',
#    'Landespolitik',
#    'Koalitionsvertrag',
#    'Richtlinien der Politik',
#    'Geschäfts\xadverteilung',
#    'Geschäfts\xadordnung',
#    'Verfassung',
#    'Senatsgalerie',
#    'Bürgermeister\xadgalerie',
#    'Senatskanzlei',
#    'Wir über uns',
#    'Abteilungen',
#    'Beschäftigtenvertretung',
#    'Smart City Berlin',
#    'Verwaltungssteuerung',
#    'Zukunftspakt',
#    'Gesamtstädtische Zielverein\xadbarungen',
#    'Berliner Verwaltungspreis',
#    'CityLAB Berlin',
#    'Aktuelles',
#    'Europaangelegenheiten',
#    'Internationales',
#    'Strategie und Ziele',
#    'Städtepartnerschaften',
#    'Städtenetzwerke',
#    'Partner',
#    'Bundesangelegenheiten',
#    'Aktuelles',
#    'Landesvertretung Berlin',
#    'Der Bundesrat',
#    'Der Deutsche Bundestag',
#    'Der Vermittlungs\xadausschuss',
#    'Die Ministerpräsident\xadenkonferenz',
#    'Die Ministerpräsi\xaddentenkonferenz Ost',
#    'Die Landes\xadvertretungen',
#    'Ausbildungs\xadmöglichkeiten',
#    'Medienpolitik',
#    'Rat der Bürgermeister',
#    'Service',
#    'Bürgerberatung',
#    'Rotes Rathaus',
#    'Baugeschichte',
#    'Steinerne Chronik',
#    'Besichtigung',
#    'Ausstellungen',
#    'Goldenes Buch',
#    'Berlin-Informationen',
#    'Zeitschrift aktuell',
#    'Publikationen',
#    'Wappen und Hoheitszeichen',
#    'Illumination Brandenburger Tor',
#    'Corporate Design',
#    'Neue Marke Berlin',
#    'Newsletter',
#    'Stellenaus\xadschreibungen',
#    'Information in other languages',
#    'English',
#    'Weiteres',
#    'twitter',
#    'facebook',
#    'instagram',
#    'linkedin',
#    'youtube',
#    'Der Regierende Bürgermeister von Berlin - Senatskanzlei',
#    'Bild: Landesarchiv Berlin / Grönboldt',
#    'Kai Wegner begrüßt Italiens Präsidenten Sergio Mattarella',
#    'Der Regierende Bürgermeister begrüßte den italienischen Präsidenten und seine Frau in Berlin am Brandenburger Tor.',
#    'Weitere Informationen',
#    'Bild:',
#    'Landesarchiv Berlin / Grönboldt',
#    'Wegner empfängt Jerusalemer Bürgermeister',
#    'Kai Wegner, empfing am 26. September den Bürgermeister von Jerusalem, Mosche Lion.',
#    'Weitere Informationen',
#    'Kai Wegner vor Ort',
#    'Der Regierende Bürgermeister besucht am 28. Oktober den Bezirk Kreuzberg-Friedrichshain und stellt sich den Fragen der Berlinerinnen und Berliner. Melden Sie sich an!',
#    'Weitere Informationen',
#    'Fokusthemen',
#    'Berlin steht vor diversen gesellschaftlichen Herausforderungen. Der Berliner Senat setzt einen Fokus auf sechs Themenschwerpunkte.',
#    'Weitere Informationen',
#    'Oft gesucht',
#    'Regierender Bürgermeister',
#    'Termine',
#    'Senatsmitglieder',
#    'Richtlinien der Politik',
#    'Fokusthemen',
#    'Rotes Rathaus',
#    'Ehrungen',
#    'Organigramm',
#    'Stellenausschreibungen',
#    'Bürgerberatung',
#    'Politische Themen',
#    'Bild: iStock.com/Bojan89',
#    'Moderne Verwaltung',
#    'Der Weg zum Amt - bald nur noch digital! Immer mehr Bürgerservices werden online angeboten.',
#    'Weitere Informationen',
#    'Bild: Sabine Zoltnere',
#    'Verwaltungssteuerung',
#    'Ziel ist die konkrete Stärkung der Dienstleistungsqualität der Berliner Verwaltung.',
#    'Weitere Informationen',
#    'Bild: Florian Reimann',
#    'Gemeinsam Digital',
#    'Visionäre Entwürfe und konkrete Baupläne: Die Smart City-Strategie für die Hauptstadt.',
#    'Weitere Informationen',
#    'Bild: Europareferat SenKultEU',
#    'Europa',
#    'Was hat Berlin mit Europa zu tun? Finden Sie es heraus!',
#    'Weitere Informationen',
#    'Bild: Landesarchiv Berlin, Wunstorf',
#    'Internationales',
#    'Das Land Berlin unterhält Partnerschaften mit 18 Metropolen auf der Welt.',
#    'Weitere Informationen',
#    'Bild: Mircea Moira / depositphotos.com',
#    'Medien',
#    'Der Senat hat das Ziel, Berlin als Filmmetropole weiter auszubauen und die Medienpolitik voranzutreiben.',
#    'Weitere Informationen',
#    'Pressemitteilungen',
#    '01.10.2024',
#    'Olympiapark wird Gebiet mit außergewöhnlicher stadtpolitischer Bedeutung',
#    '01.10.2024',
#    'Bebauungsplan ermöglicht Aufbau eines Katalyse-Forschungs- und Entwicklungszentrums',
#    '01.10.2024',
#    'Land Berlin reformiert Mietobergrenze bei Ersatzwohnraum',
#    'Weitere Pressemitteilungen',
#    'Weitere Informationen zu diesem Auftritt',
#    'Zur Startseite',
#    'zum Seitenanfang',
#    'Senatskanzlei',
#    'Impressum',
#    'Kontakt',
#    'Datenschutzerklärung',
#    'Erklärung zur Barrierefreiheit',
#    'DGS',
#    'Leichte Sprache',
#    'Fokusthemen',
#    'Moderne Verwaltung',
#    'Bauen und Wohnen',
#    'Mobilität und Verkehr',
#    'Sicherheit',
#    'Klimaschutz',
#    'Bildung',
#    'Politik',
#    'Landespolitik',
#    'Berliner Senat',
#    'Moderne Verwaltung',
#    'Europa',
#    'Internationales',
#    'Service',
#    'Bürgerberatung',
#    'Rotes Rathaus',
#    'Publikationen',
#    'Stellenausschreibungen',
#    'Ausstellungen',
#    'Fotos',
#    'Interessantes',
#    'Goldenes Buch',
#    'Ehrungen',
#    'Bürgermeistergalerie',
#    'Ukraine',
#    'Energieportal',
#    'MeinBerlin',
#    'Weitere Informationen zu Berlin.de',
#    'Service',
#    'Service-App',
#    'Termin vereinbaren',
#    'Bürgertelefon 115',
#    'Notdienste',
#    'Gewerbeservice',
#    'Behörden',
#    'Behörden A-Z',
#    'Senatsverwaltungen',
#    'Bezirksämter',
#    'Bürgerämter',
#    'Jobcenter',
#    'Einwanderungsamt',
#    'Politik & Verwaltung',
#    'Landesregierung',
#    'Karriere im Land Berlin',
#    'Bürgerbeteiligung',
#    'Open Data',
#    'Vergaben',
#    'Aktuelles',
#    'Pressemitteilungen',
#    'Polizeimeldungen',
#    'Veranstaltungen',
#    'Ukraine',
#    'Hitzeschutz',
#    'Themen',
#    'Fokusthemen',
#    'Berliner Verkehrswende',
#    'Moderne Verwaltung',
#    'Mietspiegel',
#    'Grundsteuer',
#    'Weitere Informationen',
#    'Kultur & Ausgehen',
#    'Tourismus',
#    'Wirtschaft',
#    'Stadtleben',
#    'Stadtplan',
#    'Berlin.de ist ein Angebot des Landes Berlin.']},
#  {'url': 'https://www.berlin.de//rbmskzl/leichte-sprache/',
#   'text': ['Der Regierende Bürgermeister',
#    'Senatskanzlei',
#    'Informationen und Links zur Barrierefreiheit öffnen',
#    'Barrierefrei',
#    'Barrierefreiheit',
#    'Schließen: Barrierefreiheit',
#    'Leichte Sprache',
#    'DGS',
#    'Wie barrierefrei ist diese Webseite?',
#    'Erklärung zur Barrierefreiheit',
#    'Haben Sie Anmerkungen oder Fragen zur Barrierefreiheit dieser Webseite?',
#    'Kontakt zur Ansprechperson',
#    'Wo gibt es zusätzliche Informationen zur Barrierefreiheit im Land Berlin?',
#    'Landesbeauftragte für digitale Barrierefreiheit',
#    'Suche',
#    'Suche',
#    'Suche schließen',
#    'Suche auf der Internetseite',
#    'Suchen',
#    'Menü',
#    'Hauptnavigation',
#    'Menü schließen',
#    'Aktuelles',
#    'Termine',
#    'Abonnement',
#    'Presse\xadmitteilungen',
#    '2023',
#    '2022',
#    '2021',
#    'Suche und Abonnement',
#    'Media',
#    'Veranstaltungen',
#    'Kai Wegner vor Ort',
#    'Ausstellungen',
#    'Rückblick',
#    'Auszeichnungen und Ehrungen',
#    'Ehren\xadbürgerschaft Berlins',
#    'Ehren\xadgrabstätten',
#    'Ernst-Reuter-Plakette',
#    'Verdienstorden des Landes Berlin',
#    'Stadt\xadältesten\xadwürde',
#    'Berliner Wissen\xadschafts\xadpreis',
#    'Preis\xadträgerinnen und Preisträger',
#    'Berliner Ehrennadel',
#    'Ehren\xadpatenschaft',
#    'Suche',
#    'Social Media',
#    'Regierender Bürgermeister',
#    'Fokusthemen',
#    'Moderne Verwaltung',
#    'Bauen und Wohnen',
#    'Mobilität',
#    'Sicherheit',
#    'Klimaschutz',
#    'Bildung',
#    'Leichte Sprache',
#    'Politik',
#    'Senat',
#    'Senatsmitglieder',
#    'Landespolitik',
#    'Koalitionsvertrag',
#    'Richtlinien der Politik',
#    'Geschäfts\xadverteilung',
#    'Geschäfts\xadordnung',
#    'Verfassung',
#    'Senatsgalerie',
#    'Bürgermeister\xadgalerie',
#    'Senatskanzlei',
#    'Wir über uns',
#    'Abteilungen',
#    'Beschäftigtenvertretung',
#    'Smart City Berlin',
#    'Verwaltungssteuerung',
#    'Zukunftspakt',
#    'Gesamtstädtische Zielverein\xadbarungen',
#    'Berliner Verwaltungspreis',
#    'CityLAB Berlin',
#    'Aktuelles',
#    'Europaangelegenheiten',
#    'Internationales',
#    'Strategie und Ziele',
#    'Städtepartnerschaften',
#    'Städtenetzwerke',
#    'Partner',
#    'Bundesangelegenheiten',
#    'Aktuelles',
#    'Landesvertretung Berlin',
#    'Der Bundesrat',
#    'Der Deutsche Bundestag',
#    'Der Vermittlungs\xadausschuss',
#    'Die Ministerpräsident\xadenkonferenz',
#    'Die Ministerpräsi\xaddentenkonferenz Ost',
#    'Die Landes\xadvertretungen',
#    'Ausbildungs\xadmöglichkeiten',
#    'Medienpolitik',
#    'Rat der Bürgermeister',
#    'Service',
#    'Bürgerberatung',
#    'Rotes Rathaus',
#    'Baugeschichte',
#    'Steinerne Chronik',
#    'Besichtigung',
#    'Ausstellungen',
#    'Goldenes Buch',
#    'Berlin-Informationen',
#    'Zeitschrift aktuell',
#    'Publikationen',
#    'Wappen und Hoheitszeichen',
#    'Illumination Brandenburger Tor',
#    'Corporate Design',
#    'Neue Marke Berlin',
#    'Newsletter',
#    'Stellenaus\xadschreibungen',
#    'Information in other languages',
#    'English',
#    'Weiteres',
#    'twitter',
#    'facebook',
#    'instagram',
#    'linkedin',
#    'youtube',
#    'Der Regierende Bürgermeister - Senatskanzlei',
#    'Die Senats-kanzlei von Berlin in Leichter Sprache',
#    'Direkt zur Kontaktinformation',
#    'Wir erklären Ihnen wichtige Informationen in Leichter Sprache.',
#    'Jeder soll Informationen über Berlin, den regierenden Bürger-Meister',
#    'und die Senats-Kanzlei verstehen.',
#    'Deshalb haben wir diese Internet-Seite in Leichter Sprache gemacht.',
#    'Leichte Sprache dient der Barriere-Freiheit.',
#    'Die Schrift ist groß und schwierige Wörter werden erklärt.',
#    '1.',
#    'Die Senats-Kanzlei stellt sich vor',
#    'Hier klicken und lesen',
#    '2. Die',
#    'Navigation',
#    'auf der Internet-Seite der Senats-Kanzlei',
#    'Hier klicken und lesen',
#    '3. Erklärung zur Barrierefreiheit',
#    'Hier klicken und lesen',
#    '4. Fokus-Themen der Berliner Regierung',
#    'Hier klicken und lesen',
#    'Kontakt',
#    'Der Regierende Bürgermeister von Berlin',
#    '- Senatskanzlei -',
#    'Jüdenstr. 1',
#    '10178 Berlin',
#    'Tel.:',
#    '(030) 9026-0',
#    'Fax:\xa0(030) 9026-2013',
#    'E-Mail',
#    'an den Regierenden Bürgermeister',
#    'Weitere Informationen zu diesem Auftritt',
#    'Zur Startseite',
#    'zum Seitenanfang',
#    'Senatskanzlei',
#    'Impressum',
#    'Kontakt',
#    'Datenschutzerklärung',
#    'Erklärung zur Barrierefreiheit',
#    'DGS',
#    'Leichte Sprache',
#    'Fokusthemen',
#    'Moderne Verwaltung',
#    'Bauen und Wohnen',
#    'Mobilität und Verkehr',
#    'Sicherheit',
#    'Klimaschutz',
#    'Bildung',
#    'Politik',
#    'Landespolitik',
#    'Berliner Senat',
#    'Moderne Verwaltung',
#    'Europa',
#    'Internationales',
#    'Service',
#    'Bürgerberatung',
#    'Rotes Rathaus',
#    'Publikationen',
#    'Stellenausschreibungen',
#    'Ausstellungen',
#    'Fotos',
#    'Interessantes',
#    'Goldenes Buch',
#    'Ehrungen',
#    'Bürgermeistergalerie',
#    'Ukraine',
#    'Energieportal',
#    'MeinBerlin',
#    'Weitere Informationen zu Berlin.de',
#    'Service',
#    'Service-App',
#    'Termin vereinbaren',
#    'Bürgertelefon 115',
#    'Notdienste',
#    'Gewerbeservice',
#    'Behörden',
#    'Behörden A-Z',
#    'Senatsverwaltungen',
#    'Bezirksämter',
#    'Bürgerämter',
#    'Jobcenter',
#    'Einwanderungsamt',
#    'Politik & Verwaltung',
#    'Landesregierung',
#    'Karriere im Land Berlin',
#    'Bürgerbeteiligung',
#    'Open Data',
#    'Vergaben',
#    'Aktuelles',
#    'Pressemitteilungen',
#    'Polizeimeldungen',
#    'Veranstaltungen',
#    'Ukraine',
#    'Hitzeschutz',
#    'Themen',
#    'Fokusthemen',
#    'Berliner Verkehrswende',
#    'Moderne Verwaltung',
#    'Mietspiegel',
#    'Grundsteuer',
#    'Weitere Informationen',
#    'Kultur & Ausgehen',
#    'Tourismus',
#    'Wirtschaft',
#    'Stadtleben',
#    'Stadtplan',
#    'Berlin.de ist ein Angebot des Landes Berlin.']},
#  {'url': 'https://www.berlin.de//rbmskzl/gebaerdensprache/',
#   'text': ['Der Regierende Bürgermeister',
#    'Senatskanzlei',
#    'Informationen und Links zur Barrierefreiheit öffnen',
#    'Barrierefrei',
#    'Barrierefreiheit',
#    'Schließen: Barrierefreiheit',
#    'Leichte Sprache',
#    'DGS',
#    'Wie barrierefrei ist diese Webseite?',
#    'Erklärung zur Barrierefreiheit',
#    'Haben Sie Anmerkungen oder Fragen zur Barrierefreiheit dieser Webseite?',
#    'Kontakt zur Ansprechperson',
#    'Wo gibt es zusätzliche Informationen zur Barrierefreiheit im Land Berlin?',
#    'Landesbeauftragte für digitale Barrierefreiheit',
#    'Suche',
#    'Suche',
#    'Suche schließen',
#    'Suche auf der Internetseite',
#    'Suchen',
#    'Menü',
#    'Hauptnavigation',
#    'Menü schließen',
#    'Aktuelles',
#    'Termine',
#    'Abonnement',
#    'Presse\xadmitteilungen',
#    '2023',
#    '2022',
#    '2021',
#    'Suche und Abonnement',
#    'Media',
#    'Veranstaltungen',
#    'Kai Wegner vor Ort',
#    'Ausstellungen',
#    'Rückblick',
#    'Auszeichnungen und Ehrungen',
#    'Ehren\xadbürgerschaft Berlins',
#    'Ehren\xadgrabstätten',
#    'Ernst-Reuter-Plakette',
#    'Verdienstorden des Landes Berlin',
#    'Stadt\xadältesten\xadwürde',
#    'Berliner Wissen\xadschafts\xadpreis',
#    'Preis\xadträgerinnen und Preisträger',
#    'Berliner Ehrennadel',
#    'Ehren\xadpatenschaft',
#    'Suche',
#    'Social Media',
#    'Regierender Bürgermeister',
#    'Fokusthemen',
#    'Moderne Verwaltung',
#    'Bauen und Wohnen',
#    'Mobilität',
#    'Sicherheit',
#    'Klimaschutz',
#    'Bildung',
#    'Leichte Sprache',
#    'Politik',
#    'Senat',
#    'Senatsmitglieder',
#    'Landespolitik',
#    'Koalitionsvertrag',
#    'Richtlinien der Politik',
#    'Geschäfts\xadverteilung',
#    'Geschäfts\xadordnung',
#    'Verfassung',
#    'Senatsgalerie',
#    'Bürgermeister\xadgalerie',
#    'Senatskanzlei',
#    'Wir über uns',
#    'Abteilungen',
#    'Beschäftigtenvertretung',
#    'Smart City Berlin',
#    'Verwaltungssteuerung',
#    'Zukunftspakt',
#    'Gesamtstädtische Zielverein\xadbarungen',
#    'Berliner Verwaltungspreis',
#    'CityLAB Berlin',
#    'Aktuelles',
#    'Europaangelegenheiten',
#    'Internationales',
#    'Strategie und Ziele',
#    'Städtepartnerschaften',
#    'Städtenetzwerke',
#    'Partner',
#    'Bundesangelegenheiten',
#    'Aktuelles',
#    'Landesvertretung Berlin',
#    'Der Bundesrat',
#    'Der Deutsche Bundestag',
#    'Der Vermittlungs\xadausschuss',
#    'Die Ministerpräsident\xadenkonferenz',
#    'Die Ministerpräsi\xaddentenkonferenz Ost',
#    'Die Landes\xadvertretungen',
#    'Ausbildungs\xadmöglichkeiten',
#    'Medienpolitik',
#    'Rat der Bürgermeister',
#    'Service',
#    'Bürgerberatung',
#    'Rotes Rathaus',
#    'Baugeschichte',
#    'Steinerne Chronik',
#    'Besichtigung',
#    'Ausstellungen',
#    'Goldenes Buch',
#    'Berlin-Informationen',
#    'Zeitschrift aktuell',
#    'Publikationen',
#    'Wappen und Hoheitszeichen',
#    'Illumination Brandenburger Tor',
#    'Corporate Design',
#    'Neue Marke Berlin',
#    'Newsletter',
#    'Stellenaus\xadschreibungen',
#    'Information in other languages',
#    'English',
#    'Weiteres',
#    'twitter',
#    'facebook',
#    'instagram',
#    'linkedin',
#    'youtube',
#    'Der Regierende Bürgermeister - Senatskanzlei',
#    'Die Senatskanzlei und die Berliner Verwaltung in DGS',
#    'Direkt zur Kontaktinformation',
#    'Bild: domen.grogl@gmail.com',
#    'Die Senatskanzlei in DGS',
#    'Die Berliner Senatskanzlei stellt sich und ihre Aufgaben vor.',
#    'Weitere Informationen',
#    'Bild: domen.grogl@gmail.com',
#    'Erklärung zur Barrierefreiheit',
#    'Wie barrierearm ist dieser Webauftritt? An wen kann ich mich wenden, wenn ich Fragen habe?',
#    'Weitere Informationen',
#    'Bild: Verwaltungsakademie Berlin',
#    'Die Berliner Verwaltung und das Wahlsystem in DGS',
#    'Die Aufgaben des Senats, der Haupt- und Bezirksverwaltung und das Berliner Wahlsystem.',
#    'Weitere Informationen',
#    'Kontakt',
#    'Der Regierende Bürgermeister von Berlin',
#    '- Senatskanzlei -',
#    'Landesredaktion / Koordinierung Berlin.de',
#    'Jüdenstr. 1',
#    '10178 Berlin',
#    'Tel.:',
#    '(030) 9026 24 35',
#    'Fax:\xa0(030) 9026 22 85',
#    'E-Mail',
#    'eMail an die Online-Redaktion',
#    'Homepage',
#    'Webseite der Senatskanzlei Berlin',
#    'Weitere Informationen zu diesem Auftritt',
#    'Zur Startseite',
#    'zum Seitenanfang',
#    'Senatskanzlei',
#    'Impressum',
#    'Kontakt',
#    'Datenschutzerklärung',
#    'Erklärung zur Barrierefreiheit',
#    'DGS',
#    'Leichte Sprache',
#    'Fokusthemen',
#    'Moderne Verwaltung',
#    'Bauen und Wohnen',
#    'Mobilität und Verkehr',
#    'Sicherheit',
#    'Klimaschutz',
#    'Bildung',
#    'Politik',
#    'Landespolitik',
#    'Berliner Senat',
#    'Moderne Verwaltung',
#    'Europa',
#    'Internationales',
#    'Service',
#    'Bürgerberatung',
#    'Rotes Rathaus',
#    'Publikationen',
#    'Stellenausschreibungen',
#    'Ausstellungen',
#    'Fotos',
#    'Interessantes',
#    'Goldenes Buch',
#    'Ehrungen',
#    'Bürgermeistergalerie',
#    'Ukraine',
#    'Energieportal',
#    'MeinBerlin',
#    'Weitere Informationen zu Berlin.de',
#    'Service',
#    'Service-App',
#    'Termin vereinbaren',
#    'Bürgertelefon 115',
#    'Notdienste',
#    'Gewerbeservice',
#    'Behörden',
#    'Behörden A-Z',
#    'Senatsverwaltungen',
#    'Bezirksämter',
#    'Bürgerämter',
#    'Jobcenter',
#    'Einwanderungsamt',
#    'Politik & Verwaltung',
#    'Landesregierung',
#    'Karriere im Land Berlin',
#    'Bürgerbeteiligung',
#    'Open Data',
#    'Vergaben',
#    'Aktuelles',
#    'Pressemitteilungen',
#    'Polizeimeldungen',
#    'Veranstaltungen',
#    'Ukraine',
#    'Hitzeschutz',
#    'Themen',
#    'Fokusthemen',
#    'Berliner Verkehrswende',
#    'Moderne Verwaltung',
#    'Mietspiegel',
#    'Grundsteuer',
#    'Weitere Informationen',
#    'Kultur & Ausgehen',
#    'Tourismus',
#    'Wirtschaft',
#    'Stadtleben',
#    'Stadtplan',
#    'Berlin.de ist ein Angebot des Landes Berlin.']},
#  {'url': 'https://www.berlin.de//rbmskzl/barrierefreiheitserklaerung.879589.php',
#   'text': ['Der Regierende Bürgermeister',
#    'Senatskanzlei',
#    'Informationen und Links zur Barrierefreiheit öffnen',
#    'Barrierefrei',
#    'Barrierefreiheit',
#    'Schließen: Barrierefreiheit',
#    'Leichte Sprache',
#    'DGS',
#    'Wie barrierefrei ist diese Webseite?',
#    'Erklärung zur Barrierefreiheit',
#    'Haben Sie Anmerkungen oder Fragen zur Barrierefreiheit dieser Webseite?',
#    'Kontakt zur Ansprechperson',
#    'Wo gibt es zusätzliche Informationen zur Barrierefreiheit im Land Berlin?',
#    'Landesbeauftragte für digitale Barrierefreiheit',
#    'Suche',
#    'Suche',
#    'Suche schließen',
#    'Suche auf der Internetseite',
#    'Suchen',
#    'Menü',
#    'Hauptnavigation',
#    'Menü schließen',
#    'Aktuelles',
#    'Termine',
#    'Abonnement',
#    'Presse\xadmitteilungen',
#    '2023',
#    '2022',
#    '2021',
#    'Suche und Abonnement',
#    'Media',
#    'Veranstaltungen',
#    'Kai Wegner vor Ort',
#    'Ausstellungen',
#    'Rückblick',
#    'Auszeichnungen und Ehrungen',
#    'Ehren\xadbürgerschaft Berlins',
#    'Ehren\xadgrabstätten',
#    'Ernst-Reuter-Plakette',
#    'Verdienstorden des Landes Berlin',
#    'Stadt\xadältesten\xadwürde',
#    'Berliner Wissen\xadschafts\xadpreis',
#    'Preis\xadträgerinnen und Preisträger',
#    'Berliner Ehrennadel',
#    'Ehren\xadpatenschaft',
#    'Suche',
#    'Social Media',
#    'Regierender Bürgermeister',
#    'Fokusthemen',
#    'Moderne Verwaltung',
#    'Bauen und Wohnen',
#    'Mobilität',
#    'Sicherheit',
#    'Klimaschutz',
#    'Bildung',
#    'Leichte Sprache',
#    'Politik',
#    'Senat',
#    'Senatsmitglieder',
#    'Landespolitik',
#    'Koalitionsvertrag',
#    'Richtlinien der Politik',
#    'Geschäfts\xadverteilung',
#    'Geschäfts\xadordnung',
#    'Verfassung',
#    'Senatsgalerie',
#    'Bürgermeister\xadgalerie',
#    'Senatskanzlei',
#    'Wir über uns',
#    'Abteilungen',
#    'Beschäftigtenvertretung',
#    'Smart City Berlin',
#    'Verwaltungssteuerung',
#    'Zukunftspakt',
#    'Gesamtstädtische Zielverein\xadbarungen',
#    'Berliner Verwaltungspreis',
#    'CityLAB Berlin',
#    'Aktuelles',
#    'Europaangelegenheiten',
#    'Internationales',
#    'Strategie und Ziele',
#    'Städtepartnerschaften',
#    'Städtenetzwerke',
#    'Partner',
#    'Bundesangelegenheiten',
#    'Aktuelles',
#    'Landesvertretung Berlin',
#    'Der Bundesrat',
#    'Der Deutsche Bundestag',
#    'Der Vermittlungs\xadausschuss',
#    'Die Ministerpräsident\xadenkonferenz',
#    'Die Ministerpräsi\xaddentenkonferenz Ost',
#    'Die Landes\xadvertretungen',
#    'Ausbildungs\xadmöglichkeiten',
#    'Medienpolitik',
#    'Rat der Bürgermeister',
#    'Service',
#    'Bürgerberatung',
#    'Rotes Rathaus',
#    'Baugeschichte',
#    'Steinerne Chronik',
#    'Besichtigung',
#    'Ausstellungen',
#    'Goldenes Buch',
#    'Berlin-Informationen',
#    'Zeitschrift aktuell',
#    'Publikationen',
#    'Wappen und Hoheitszeichen',
#    'Illumination Brandenburger Tor',
#    'Corporate Design',
#    'Neue Marke Berlin',
#    'Newsletter',
#    'Stellenaus\xadschreibungen',
#    'Information in other languages',
#    'English',
#    'Weiteres',
#    'twitter',
#    'facebook',
#    'instagram',
#    'linkedin',
#    'youtube',
#    'Der Regierende Bürgermeister - Senatskanzlei',
#    'Barrierefreiheitserklärung der Senatskanzlei',
#    'Zur Erklärung zur Barrierefreiheit in Leichter Sprache',
#    'Zur Erklärung zur Barrierefreiheit in DGS',
#    'Öffentliche Stelle / Geltungsbereich',
#    'Senatskanzlei Berlin',
#    'Wir bemühen uns,\n         unseren Webauftritt         barrierefrei zu gestalten.\n        Die Erklärung zur digitalen Barrierefreiheit wird im Gesetz über die barrierefreie Informations- und Kommunikationstechnik Berlin (BIKTG Bln) verlangt.\n        Die technischen Anforderungen zur Barrierefreiheit ergeben sich aus der aktuellen Barrierefreie-Informationstechnik-Verordnung (BITV).',
#    'Diese Erklärung zur digitalen Barrierefreiheit gilt für das Angebot\n         Webauftritt          https://www.berlin.de/rbmskzl/.',
#    'Wann wurde die Erklärung zur Barrierefreiheit erstellt bzw. aktualisiert?',
#    'Diese Erklärung wurde am 29.07.2024 erstellt bzw. überarbeitet.',
#    'Die Überprüfung der digitalen Barrierefreiheit wurde durchgeführt von\n                    der oben aufgeführten öffentlichen Stelle durch eine Selbstbewertung.',
#    'Wie barrierefrei ist das Angebot?',
#    'Dieser Webauftritt / Diese Anwendung ist nur teilweise barrierefrei. Es werden nur teilweise die Anforderungen der aktuellen BITV erfüllt.',
#    'Welche Bereiche sind nicht barrierefrei?',
#    'Die nachstehend aufgeführten Bereiche sind aus folgenden Gründen nicht barrierefrei:',
#    'Barriere: Ausgewählte Seite nicht ausgezeichnet',
#    'Beschreibung: Aria-Attribut für ausgewählte Seite nicht vorhanden.',
#    'Maßnahmen: Aria-Attribut wird ergänzt.',
#    'Zeitplan: Behebung in 2024',
#    'Barriere: Deaktivierte Elemente',
#    'Beschreibung: Deaktivierte Elemente sind teilweise nicht ausgezeichnet.',
#    'Maßnahmen: Deaktivierte Elemente werden ausgezeichnet.',
#    'Zeitplan: Behebung in 2024',
#    'Barriere: Grafiken und Bedienelemente',
#    'Beschreibung: Einige Logos und Bedienelemente werden nicht kontrastreich dargestellt, wenn die Farbe im Browser angepasst wird.',
#    'Maßnahmen: Anpassung der Logos und Bedienelemente.',
#    'Zeitplan: Behebung in 2024',
#    'Barriere: strukturierte Formulare',
#    'Beschreibung: Auf den Seiten existieren Formulare, bei denen teilweise Strukturelemente fehlen bzw. fehlerhaft verwendet werden. Entsprechend können beim Einsatz von Screenreadern für die Nutzung relevante Informationen fehlen oder nicht korrekt verstanden werden.',
#    'Maßnahmen: Strukturelemente der Formulare werden korrigiert.',
#    'Zeitplan: Behebung in 2024',
#    'Barriere: Dokumente',
#    'Beschreibung: Nicht alle hochgeladenen Dokumente sind bereits barrierearm. Dies betrifft vor allem Organigramme, Broschüren und Berichte.',
#    'Maßnahmen: Mit der Einführung des BerlinPCs sollen allen Mitarbeiterinnen und Mitarbeitern entsprechende Software zum Prüfen und zur Bearbeitung von Dokumenten zur Verfügung stehen.',
#    'Zeitplan: Die Einführung des BerlinPC ist nicht vor 2025 in der Senatskanzlei geplant.',
#    'Kein Anwendungsfall',
#    'Diese Inhalte fallen nicht in den Anwendungsbereich des Barrierefreien IKT Gesetzes Berlin.',
#    'Ausnahmen, die nicht barrierefrei sein müssen:',
#    'Barriere: Archiv',
#    'Beschreibung: Pressemitteilungen 2014-2023',
#    'Rechtsgrundlage: BIKTG Bln §4 Abs. 4h',
#    'Wen können Sie bei Anmerkungen oder Fragen zur digitalen Barrierefreiheit (Feedbackoption) kontaktieren?',
#    'Sie möchten Informationen zur Umsetzung der Barrierefreiheit oder bestehende Barrieren melden? Sie\n        können etwas auf unserer Website oder der mobilen Anwendung nicht ausreichend wahrnehmen, bedienen\n        oder verstehen? Sie benötigen Informationen in einer barrierefreien Form? Dann informieren\n        Sie uns bitte.',
#    'Kontakt zur Ansprechperson der öffentlichen Stelle:',
#    'Name: Stephan Neumann',
#    'E-Mail:',
#    'barrierefreiheit@senatskanzlei.berlin.de',
#    'Telefon:',
#    '(030) 9026 2365',
#    'Kontakt zur Landesbeauftragten für digitale Barrierefreiheit',
#    'Die folgenden Angaben werden in der digitalen Barrierefreiheitserklärung immer ausgegeben:\n        Wenn Ihre Kontaktaufnahme mit der öffentlichen Stelle nicht erfolgreich war, Sie innerhalb von 4 Wochen\n        keine Antwort erhalten haben, oder die Antwort unzureichend war, können Sie sich an die Landesbeauftragte\n        für digitale Barrierefreiheit wenden und ein Durchsetzungsverfahren anstreben. Bitte kontaktieren Sie immer\n        zuerst die betroffene öffentliche Stelle!',
#    'Link zum Kontaktformular',
#    'Weitere Informationen zur Landesbeauftragten für digitale Barrierefreiheit',
#    'Weitere Informationen zu diesem Auftritt',
#    'Zur Startseite',
#    'zum Seitenanfang',
#    'Senatskanzlei',
#    'Impressum',
#    'Kontakt',
#    'Datenschutzerklärung',
#    'Erklärung zur Barrierefreiheit',
#    'DGS',
#    'Leichte Sprache',
#    'Fokusthemen',
#    'Moderne Verwaltung',
#    'Bauen und Wohnen',
#    'Mobilität und Verkehr',
#    'Sicherheit',
#    'Klimaschutz',
#    'Bildung',
#    'Politik',
#    'Landespolitik',
#    'Berliner Senat',
#    'Moderne Verwaltung',
#    'Europa',
#    'Internationales',
#    'Service',
#    'Bürgerberatung',
#    'Rotes Rathaus',
#    'Publikationen',
#    'Stellenausschreibungen',
#    'Ausstellungen',
#    'Fotos',
#    'Interessantes',
#    'Goldenes Buch',
#    'Ehrungen',
#    'Bürgermeistergalerie',
#    'Ukraine',
#    'Energieportal',
#    'MeinBerlin',
#    'Weitere Informationen zu Berlin.de',
#    'Service',
#    'Service-App',
#    'Termin vereinbaren',
#    'Bürgertelefon 115',
#    'Notdienste',
#    'Gewerbeservice',
#    'Behörden',
#    'Behörden A-Z',
#    'Senatsverwaltungen',
#    'Bezirksämter',
#    'Bürgerämter',
#    'Jobcenter',
#    'Einwanderungsamt',
#    'Politik & Verwaltung',
#    'Landesregierung',
#    'Karriere im Land Berlin',
#    'Bürgerbeteiligung',
#    'Open Data',
#    'Vergaben',
#    'Aktuelles',
#    'Pressemitteilungen',
#    'Polizeimeldungen',
#    'Veranstaltungen',
#    'Ukraine',
#    'Hitzeschutz',
#    'Themen',
#    'Fokusthemen',
#    'Berliner Verkehrswende',
#    'Moderne Verwaltung',
#    'Mietspiegel',
#    'Grundsteuer',
#    'Weitere Informationen',
#    'Kultur & Ausgehen',
#    'Tourismus',
#    'Wirtschaft',
#    'Stadtleben',
#    'Stadtplan',
#    'Berlin.de ist ein Angebot des Landes Berlin.']},
#  {'url': 'https://www.berlin.de//rbmskzl/barrierefreiheitserklaerung.879589.php#contactbfe',
#   'text': ['Der Regierende Bürgermeister',
#    'Senatskanzlei',
#    'Informationen und Links zur Barrierefreiheit öffnen',
#    'Barrierefrei',
#    'Barrierefreiheit',
#    'Schließen: Barrierefreiheit',
#    'Leichte Sprache',
#    'DGS',
#    'Wie barrierefrei ist diese Webseite?',
#    'Erklärung zur Barrierefreiheit',
#    'Haben Sie Anmerkungen oder Fragen zur Barrierefreiheit dieser Webseite?',
#    'Kontakt zur Ansprechperson',
#    'Wo gibt es zusätzliche Informationen zur Barrierefreiheit im Land Berlin?',
#    'Landesbeauftragte für digitale Barrierefreiheit',
#    'Suche',
#    'Suche',
#    'Suche schließen',
#    'Suche auf der Internetseite',
#    'Suchen',
#    'Menü',
#    'Hauptnavigation',
#    'Menü schließen',
#    'Aktuelles',
#    'Termine',
#    'Abonnement',
#    'Presse\xadmitteilungen',
#    '2023',
#    '2022',
#    '2021',
#    'Suche und Abonnement',
#    'Media',
#    'Veranstaltungen',
#    'Kai Wegner vor Ort',
#    'Ausstellungen',
#    'Rückblick',
#    'Auszeichnungen und Ehrungen',
#    'Ehren\xadbürgerschaft Berlins',
#    'Ehren\xadgrabstätten',
#    'Ernst-Reuter-Plakette',
#    'Verdienstorden des Landes Berlin',
#    'Stadt\xadältesten\xadwürde',
#    'Berliner Wissen\xadschafts\xadpreis',
#    'Preis\xadträgerinnen und Preisträger',
#    'Berliner Ehrennadel',
#    'Ehren\xadpatenschaft',
#    'Suche',
#    'Social Media',
#    'Regierender Bürgermeister',
#    'Fokusthemen',
#    'Moderne Verwaltung',
#    'Bauen und Wohnen',
#    'Mobilität',
#    'Sicherheit',
#    'Klimaschutz',
#    'Bildung',
#    'Leichte Sprache',
#    'Politik',
#    'Senat',
#    'Senatsmitglieder',
#    'Landespolitik',
#    'Koalitionsvertrag',
#    'Richtlinien der Politik',
#    'Geschäfts\xadverteilung',
#    'Geschäfts\xadordnung',
#    'Verfassung',
#    'Senatsgalerie',
#    'Bürgermeister\xadgalerie',
#    'Senatskanzlei',
#    'Wir über uns',
#    'Abteilungen',
#    'Beschäftigtenvertretung',
#    'Smart City Berlin',
#    'Verwaltungssteuerung',
#    'Zukunftspakt',
#    'Gesamtstädtische Zielverein\xadbarungen',
#    'Berliner Verwaltungspreis',
#    'CityLAB Berlin',
#    'Aktuelles',
#    'Europaangelegenheiten',
#    'Internationales',
#    'Strategie und Ziele',
#    'Städtepartnerschaften',
#    'Städtenetzwerke',
#    'Partner',
#    'Bundesangelegenheiten',
#    'Aktuelles',
#    'Landesvertretung Berlin',
#    'Der Bundesrat',
#    'Der Deutsche Bundestag',
#    'Der Vermittlungs\xadausschuss',
#    'Die Ministerpräsident\xadenkonferenz',
#    'Die Ministerpräsi\xaddentenkonferenz Ost',
#    'Die Landes\xadvertretungen',
#    'Ausbildungs\xadmöglichkeiten',
#    'Medienpolitik',
#    'Rat der Bürgermeister',
#    'Service',
#    'Bürgerberatung',
#    'Rotes Rathaus',
#    'Baugeschichte',
#    'Steinerne Chronik',
#    'Besichtigung',
#    'Ausstellungen',
#    'Goldenes Buch',
#    'Berlin-Informationen',
#    'Zeitschrift aktuell',
#    'Publikationen',
#    'Wappen und Hoheitszeichen',
#    'Illumination Brandenburger Tor',
#    'Corporate Design',
#    'Neue Marke Berlin',
#    'Newsletter',
#    'Stellenaus\xadschreibungen',
#    'Information in other languages',
#    'English',
#    'Weiteres',
#    'twitter',
#    'facebook',
#    'instagram',
#    'linkedin',
#    'youtube',
#    'Der Regierende Bürgermeister - Senatskanzlei',
#    'Barrierefreiheitserklärung der Senatskanzlei',
#    'Zur Erklärung zur Barrierefreiheit in Leichter Sprache',
#    'Zur Erklärung zur Barrierefreiheit in DGS',
#    'Öffentliche Stelle / Geltungsbereich',
#    'Senatskanzlei Berlin',
#    'Wir bemühen uns,\n         unseren Webauftritt         barrierefrei zu gestalten.\n        Die Erklärung zur digitalen Barrierefreiheit wird im Gesetz über die barrierefreie Informations- und Kommunikationstechnik Berlin (BIKTG Bln) verlangt.\n        Die technischen Anforderungen zur Barrierefreiheit ergeben sich aus der aktuellen Barrierefreie-Informationstechnik-Verordnung (BITV).',
#    'Diese Erklärung zur digitalen Barrierefreiheit gilt für das Angebot\n         Webauftritt          https://www.berlin.de/rbmskzl/.',
#    'Wann wurde die Erklärung zur Barrierefreiheit erstellt bzw. aktualisiert?',
#    'Diese Erklärung wurde am 29.07.2024 erstellt bzw. überarbeitet.',
#    'Die Überprüfung der digitalen Barrierefreiheit wurde durchgeführt von\n                    der oben aufgeführten öffentlichen Stelle durch eine Selbstbewertung.',
#    'Wie barrierefrei ist das Angebot?',
#    'Dieser Webauftritt / Diese Anwendung ist nur teilweise barrierefrei. Es werden nur teilweise die Anforderungen der aktuellen BITV erfüllt.',
#    'Welche Bereiche sind nicht barrierefrei?',
#    'Die nachstehend aufgeführten Bereiche sind aus folgenden Gründen nicht barrierefrei:',
#    'Barriere: Ausgewählte Seite nicht ausgezeichnet',
#    'Beschreibung: Aria-Attribut für ausgewählte Seite nicht vorhanden.',
#    'Maßnahmen: Aria-Attribut wird ergänzt.',
#    'Zeitplan: Behebung in 2024',
#    'Barriere: Deaktivierte Elemente',
#    'Beschreibung: Deaktivierte Elemente sind teilweise nicht ausgezeichnet.',
#    'Maßnahmen: Deaktivierte Elemente werden ausgezeichnet.',
#    'Zeitplan: Behebung in 2024',
#    'Barriere: Grafiken und Bedienelemente',
#    'Beschreibung: Einige Logos und Bedienelemente werden nicht kontrastreich dargestellt, wenn die Farbe im Browser angepasst wird.',
#    'Maßnahmen: Anpassung der Logos und Bedienelemente.',
#    'Zeitplan: Behebung in 2024',
#    'Barriere: strukturierte Formulare',
#    'Beschreibung: Auf den Seiten existieren Formulare, bei denen teilweise Strukturelemente fehlen bzw. fehlerhaft verwendet werden. Entsprechend können beim Einsatz von Screenreadern für die Nutzung relevante Informationen fehlen oder nicht korrekt verstanden werden.',
#    'Maßnahmen: Strukturelemente der Formulare werden korrigiert.',
#    'Zeitplan: Behebung in 2024',
#    'Barriere: Dokumente',
#    'Beschreibung: Nicht alle hochgeladenen Dokumente sind bereits barrierearm. Dies betrifft vor allem Organigramme, Broschüren und Berichte.',
#    'Maßnahmen: Mit der Einführung des BerlinPCs sollen allen Mitarbeiterinnen und Mitarbeitern entsprechende Software zum Prüfen und zur Bearbeitung von Dokumenten zur Verfügung stehen.',
#    'Zeitplan: Die Einführung des BerlinPC ist nicht vor 2025 in der Senatskanzlei geplant.',
#    'Kein Anwendungsfall',
#    'Diese Inhalte fallen nicht in den Anwendungsbereich des Barrierefreien IKT Gesetzes Berlin.',
#    'Ausnahmen, die nicht barrierefrei sein müssen:',
#    'Barriere: Archiv',
#    'Beschreibung: Pressemitteilungen 2014-2023',
#    'Rechtsgrundlage: BIKTG Bln §4 Abs. 4h',
#    'Wen können Sie bei Anmerkungen oder Fragen zur digitalen Barrierefreiheit (Feedbackoption) kontaktieren?',
#    'Sie möchten Informationen zur Umsetzung der Barrierefreiheit oder bestehende Barrieren melden? Sie\n        können etwas auf unserer Website oder der mobilen Anwendung nicht ausreichend wahrnehmen, bedienen\n        oder verstehen? Sie benötigen Informationen in einer barrierefreien Form? Dann informieren\n        Sie uns bitte.',
#    'Kontakt zur Ansprechperson der öffentlichen Stelle:',
#    'Name: Stephan Neumann',
#    'E-Mail:',
#    'barrierefreiheit@senatskanzlei.berlin.de',
#    'Telefon:',
#    '(030) 9026 2365',
#    'Kontakt zur Landesbeauftragten für digitale Barrierefreiheit',
#    'Die folgenden Angaben werden in der digitalen Barrierefreiheitserklärung immer ausgegeben:\n        Wenn Ihre Kontaktaufnahme mit der öffentlichen Stelle nicht erfolgreich war, Sie innerhalb von 4 Wochen\n        keine Antwort erhalten haben, oder die Antwort unzureichend war, können Sie sich an die Landesbeauftragte\n        für digitale Barrierefreiheit wenden und ein Durchsetzungsverfahren anstreben. Bitte kontaktieren Sie immer\n        zuerst die betroffene öffentliche Stelle!',
#    'Link zum Kontaktformular',
#    'Weitere Informationen zur Landesbeauftragten für digitale Barrierefreiheit',
#    'Weitere Informationen zu diesem Auftritt',
#    'Zur Startseite',
#    'zum Seitenanfang',
#    'Senatskanzlei',
#    'Impressum',
#    'Kontakt',
#    'Datenschutzerklärung',
#    'Erklärung zur Barrierefreiheit',
#    'DGS',
#    'Leichte Sprache',
#    'Fokusthemen',
#    'Moderne Verwaltung',
#    'Bauen und Wohnen',
#    'Mobilität und Verkehr',
#    'Sicherheit',
#    'Klimaschutz',
#    'Bildung',
#    'Politik',
#    'Landespolitik',
#    'Berliner Senat',
#    'Moderne Verwaltung',
#    'Europa',
#    'Internationales',
#    'Service',
#    'Bürgerberatung',
#    'Rotes Rathaus',
#    'Publikationen',
#    'Stellenausschreibungen',
#    'Ausstellungen',
#    'Fotos',
#    'Interessantes',
#    'Goldenes Buch',
#    'Ehrungen',
#    'Bürgermeistergalerie',
#    'Ukraine',
#    'Energieportal',
#    'MeinBerlin',
#    'Weitere Informationen zu Berlin.de',
#    'Service',
#    'Service-App',
#    'Termin vereinbaren',
#    'Bürgertelefon 115',
#    'Notdienste',
#    'Gewerbeservice',
#    'Behörden',
#    'Behörden A-Z',
#    'Senatsverwaltungen',
#    'Bezirksämter',
#    'Bürgerämter',
#    'Jobcenter',
#    'Einwanderungsamt',
#    'Politik & Verwaltung',
#    'Landesregierung',
#    'Karriere im Land Berlin',
#    'Bürgerbeteiligung',
#    'Open Data',
#    'Vergaben',
#    'Aktuelles',
#    'Pressemitteilungen',
#    'Polizeimeldungen',
#    'Veranstaltungen',
#    'Ukraine',
#    'Hitzeschutz',
#    'Themen',
#    'Fokusthemen',
#    'Berliner Verkehrswende',
#    'Moderne Verwaltung',
#    'Mietspiegel',
#    'Grundsteuer',
#    'Weitere Informationen',
#    'Kultur & Ausgehen',
#    'Tourismus',
#    'Wirtschaft',
#    'Stadtleben',
#    'Stadtplan',
#    'Berlin.de ist ein Angebot des Landes Berlin.']}]

# %% [markdown]
# #### Creating a diachronic corpus of press-releases

# %% [markdown]
# *To be continued*
